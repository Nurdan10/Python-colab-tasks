# %% [markdown]
# **open()**: Dosyayı açmak için kullanılır;
# ```
# f = open(dosya_adi, "r") #Dosya okuma amaçlı açıldı
# f = open(dosya_adi, "w") #Dosya yazma amaçlı açıldı
# f = open(dosya_adi, "a") #Dosya ekleme (hem okuma hem de yazma) amaçlı açıldı.
# ```
# **write()** : Dosyaya istenen veriyi yazar. Eğer satır satır yazdırmak istenirse metin içerisinde ‘\n’ karakteri kullanılır.
#
# **writelines()** : Dosyaya verilen listeyi (birden fazla satırlık veriyi) yazar.
#
# **read(n)** : Dosyadan n karakterlik veri okur.
#
# **read()**  : Tüm dosyayı okur, sonucu string olarak döndürür.
#
# **readline()** : Dosyadan satır satır veri okur.
#
# **readlines()** :Tüm dosyayı okur, sonucu liste olarak döndürür.
#
# **seek(n)**: Dosya işaretçisinin belirttiği n. kayıta gider.
#
# **tell()**: Dosya işaretçisinin pozisyonunu ( dosya başına göre ) verir.
#
# **close()** : Dosyayı kapatır

# %%
"""Python dilinde dosya açma/kapama işlemleri için iki farklı yapı kullanılır."""

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
with open('dummy_file.txt', 'w', encoding="utf-8") as f:
    for i in range(5):
        f.write("adim\n")
# We can check that the file has been automatically closed.
f.closed # dosya kapatıldı mı?

# %%
# dosya modları(açılış amaçları)
"""
'r' : open for reading (default)
'w' : open for writing, truncating the file first
'x' : open for exclusive creation, failing if the file already exists
'a' : open for writing, appending to the end of file if it exists

'b' : binary mode
't' : text mode (default)
'+' : open for updating (r+ :reading and writing)
"""

# %%
type(open('istiklal.txt', 'rb'))

# %%
type(open('istiklal.txt', 'rt'))

# %%
with open('dummy_file.txt', mode='w', encoding="utf-8") as f:
    f.write("This is the line for my file")

with open('dummy_file.txt', mode='r', encoding="utf-8") as f:
    print(f.read())

# %%
with open('dummy_file.txt', mode='w+', encoding="utf-8") as f:
    f.write("This is the line for my file")
    f.seek(0)  # dosya başına konumlanarak kayıtları oku
    print(f.read())

# %%
with open('dummy_file.txt', mode='w', encoding="utf-8") as fw:
    fw.write("This is first line")
    fw.write("This is second line")
    fw.write("This is third line\n")
    fw.write("This is forth line")
    fw.write("This is last line")

with open('dummy_file.txt', mode='r', encoding="utf-8") as fr:
    print(fr.read())

# %%
fruits = ['Banana', 'Orange', 'Apple', 'Strawberry', 'Cherry']
f = open("fruits.txt",'w')
for i in fruits:
  f.write(i)
  f.write("\n")
f.close()

f = open("fruits.txt",'r')
print(f.readlines())
f.close()

# %%
fruits = ['Banana', 'Orange', 'Apple', 'Strawberry', 'Cherry']
with open("fruits.txt", 'w') as dosya:
    for i in fruits:
        dosya.write(i+'\n')

with open("fruits.txt", 'r',) as dosya:
    print(dosya.readlines())

# %%
with open("fruits.txt", 'r',) as dosya:
    print(dosya.read())

# %%
flowers = ["Jasmine", "Rose", "Lily", "Daisy", "Tulip"]
with open ("flowers.txt", "w", encoding="utf-8") as text:
  for i in flowers:
    text.write(i+ "\n\n")
with open ("flowers.txt", "r", encoding= "utf-8") as text:
    print(text.read())

# %%
flowers = ["Jasmine", "Rose", "Lily", "Daisy", "Tulip"]
with open ("flowers.txt", "w+", encoding="utf-8") as text:
    for i in flowers:
        text.write(i+ "\n\n")
    text.seek(0)
    print(text.read())

# %%
with open ("module1.py", "w") as fs:
    fs.write("bir")
    fs.write("iki")
    fs.write("uc\n")
    fs.write("dört")
    print(fs.write("bes"))  # ?? niye len gibi davrandı....

with open ("module1.py", "r") as fr:
    print(fr.readlines())

# %%
fruits = ['Banana\n', 'Orange\n', 'Apple\n', 'Strawberry\n', 'Cherry\n']
with open("fruits2.txt", 'w') as dosya:
    dosya.writelines(fruits)

with open("fruits2.txt", 'r',) as dosya:
    print(dosya.readlines())

with open("fruits2.txt", 'r',) as dosya:
    print(dosya.read())

# %%
flowers = ["Jasmine\n", "Rose\n", "Lily\n", "Daisy\n", "Tulip\n"]
with open ("flowers.txt", "w", encoding="utf-8") as text:
    text.writelines(flowers)

with open ("flowers.txt", "r", encoding="utf-8") as text:
    print(text.read())

# %%
#append modu : dosya yoksa dosayı oluşturur
with open("ekle.txt", mode="a") as f:
    f.write("melon")

# %%
#append modu : dosya varsa dosyaya kayıtları en son kayıttan başlayarak ekler
with open("fruits.txt", mode="a") as f:
    f.write("melon\n")

# %%
with open ("fruits.txt", "r", encoding="utf-8") as text:
    print(text.read())

# %%
with open ("fruits.txt", "r", encoding="utf-8") as text:
    print(text.readlines())

# %%
with open('flowers.txt', 'a') as file:
  file.write('Orchid\n')
  file.write('Morchid\n')

with open('flowers.txt', 'r') as file:
  print(file.read())

# %%
import os
os.getcwd()  # çalışma klasörü

# %%
with open('/content/dosya/proje/cicek.txt', 'a') as file:
  file.write('Orchid\n')
  file.write('Morchid\n')

# %%
with open('/content/dosya/proje/cicek.txt', 'r') as file:
  print(file.read())

# %%
my_file = open("istiklal.txt",'r')
my_file2 = open("istiklal2.txt",'w')
count = 0
for i in my_file.readlines():
  my_file2.writelines(i)
  count += 1
  if count%4==0 and count!=40:
    my_file2.writelines('\n')
  else:
   continue
my_file.close()
my_file2.close()

# %%
MY_PATH = '/content/istiklal.txt'
my_string = ''
with open(MY_PATH, mode = 'r') as my_file:
    for i in range(0,10):
        if i == 9:
            for _ in range(0,5):
                my_string += my_file.readline()
        else:
            for _ in range(0,4):
                my_string += my_file.readline()
            my_string += '\n'


with open('istiklal2.txt', 'w') as my_file2:
    my_file2.write(my_string)

# %%
MY_PATH = '/content/istiklal.txt'
my_list = []
with open(MY_PATH, mode = 'r') as my_file:
    my_list = my_file.readlines()
    for i in range(4,45,5):  # 45 yerine: len(my_list)+5
        my_list.insert(i, "\n")

with open('istiklal2.txt', 'w') as my_file2:
    my_file2.writelines(my_list)

# %%
my_list = []
with open("istiklal.txt", mode = 'r') as my_file, open('istiklal2.txt', 'w') as my_file2:
    my_list = my_file.readlines()
    for i in range(4,45,5):  # 45 yerine: len(my_list)+5
        my_list.insert(i, "\n")

    my_file2.writelines(my_list)

# %% [markdown]
# csv file okuma

# %%
#1. standart dosya metotlarını kullanabiliriz;
with open("fruit.csv", "r") as f:
    print(f.read())

# %%
with open("people.csv", "r") as f:
    print(f.read())

# %%
#2. yöntem csv modülünü kullanmak
import csv
# reader, writer, DictReader, DictReader
with open("people.csv", "r", newline="") as f:
    csv_nesnesi = csv.reader(f)
    for i in csv_nesnesi:
        print(i)

# %%
#2. yöntem csv modülünü kullanmak
import csv
# reader, writer, DictReader, DictReader
with open("people.csv", "r", newline="") as f:
    csv_nesnesi = csv.reader(f, delimiter=":")
    # olmayan bir karakter ile dilimlediğimizde tüm satırı tek bir string olarak algılar
    for i in csv_nesnesi:
        print(i)

# %%
import csv
# reader, writer, DictReader, DictReader
with open("people.csv", "r", newline="") as f:
    csv_nesnesi = csv.reader(f)
    for i in csv_nesnesi:
        print(*i)

# %%
help(csv.reader)

# %%
#1. csv modülünün metotlarını kullanabiliriz;
import csv
with open("fruit.csv", "r") as f:
    for i in csv.reader(f, delimiter=":"):
        print(*i)

# %%
person_list = """num, first_name, last_name, age
1, Lara, Bold, 34
2, Jhon, Smith, 23
3, Bill, Gates, 45
4, Noah, Adam, 44
5, Adam, Smith, 56
"""
#yazma
with open("person.csv", "w") as fw:
    fw.writelines(person_list)

#okuma
with open("person.csv", "r") as fr:
    print(fr.read())

# %%
# resim dosyasını ("cars2.jpeg") nasıl okuruz
with open("cars2.jpeg", mode="rb") as fb:
    print(fb.read())

# %%
# PIL, opencv gibi modül/paketlerle orjinal halini görebiliriz.

# %%
from PIL import Image
Image.open("/content/cars2.jpeg")

# %%
# Bir sonraki derste bir takip programı
def menu():
    print("1-Kayıt Ekle")
    print("2-Kayıt Listele")
    print("3-Kayıt Ara")
    print("4-Kayıt Sil")
    print("5-Kayıt Güncelle")
    print("6-Çıkış")

    while(secim:=int("Seçiminiz[1-6]..:")):
        if secim==1:
            kayit_ekle()
        elif secim==2:
            kayit_listele()
        elif secim==3:
            kayit_ara()
        elif secim==4:
            kayit_sil()
        elif secim==5:
            kayit_guncelle()
        elif secim==6:
            print("Program sonlandırıldı")
            break
        else:
            print("Lütfen [1-6] arası seçim yapınız")
if __name__=="__main__":
    menu()
